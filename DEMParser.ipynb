# %%
import sys
from demoparser.demofile import DemoFile
import matplotlib.pyplot as plt
import time

#Allow graphs to open in a window instead of inline
# %matplotlib qt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8b38d10422e1> in <module>
#       5
#       6 #Allow graphs to open in a window instead of inline
# ----> 7 get_ipython().run_line_magic('matplotlib', 'qt')
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-108> in matplotlib(self, line)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3382                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3383
# -> 3384         pt.activate_matplotlib(backend)
#    3385         pt.configure_inline_support(self, backend)
#    3386
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     312
#     313     import matplotlib.pyplot
# --> 314     matplotlib.pyplot.switch_backend(backend)
#     315
#     316     # This must be imported last in the matplotlib series, after
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in switch_backend(newbackend)
#     213         else "matplotlib.backends.backend_{}".format(newbackend.lower()))
#     214
# --> 215     backend_mod = importlib.import_module(backend_name)
#     216     Backend = type(
#     217         "Backend", (matplotlib.backends._Backend,), vars(backend_mod))
#
# /usr/lib/python3.6/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_qt5agg.py in <module>
#       9 from .. import cbook
#      10 from .backend_agg import FigureCanvasAgg
# ---> 11 from .backend_qt5 import (
#      12     QtCore, QtGui, QtWidgets, _BackendQT5, FigureCanvasQT, FigureManagerQT,
#      13     NavigationToolbar2QT, backend_version)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in <module>
#      13     _Backend, FigureCanvasBase, FigureManagerBase, NavigationToolbar2,
#      14     TimerBase, cursors, ToolContainerBase, StatusbarBase, MouseButton)
# ---> 15 import matplotlib.backends.qt_editor.figureoptions as figureoptions
#      16 from matplotlib.backends.qt_editor.formsubplottool import UiSubplotTool
#      17 from matplotlib.backend_managers import ToolManager
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/qt_editor/figureoptions.py in <module>
#      11 import matplotlib
#      12 from matplotlib import cm, colors as mcolors, markers, image as mimage
# ---> 13 from matplotlib.backends.qt_compat import QtGui
#      14 from matplotlib.backends.qt_editor import _formlayout
#      15
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/qt_compat.py in <module>
#     156         break
#     157     else:
# --> 158         raise ImportError("Failed to import any qt binding")
#     159 else:  # We should not get there.
#     160     raise AssertionError("Unexpected QT_API: {}".format(QT_API))
#
# ImportError: Failed to import any qt binding

# %%
#Global Variables
g_map_xrange = range()
g_map_yrange = range()

# %%
#Encapsulates all information about each individual player
class Person:
    def __init__ (self, name, team):
        self.m_name = name
        self.m_team = team
        self.m_position_history = {
                                    'dead' : [],
                                    'position': [],
                                    'view_angle' : [],
                                    'spotted' : []
                                    }
        self.m_dead = 'N'
        
    def update_position (self, pos, angle, spotted, dead):
        #current position is now at m_position_history[-1]
        if self.m_dead == 'Y': return
        if dead == 'Y': self.m_dead = 'Y'
        
        self.m_position_history['position'].append(pos)
        self.m_position_history['view_angle'].append(angle)
        self.m_position_history['dead'].append(dead)
        self.m_position_history['spotted'].append(spotted)

# %%
#Encapsulates parsed information from DEM file about each round, no interesting processing is conducted here.
class Round:
    def __init__ (self,rid):
        self.m_rid = rid
        self.m_players = dict()
        self.m_number_frames = 0
    
    
    def add_player (self,player):
        #Add person type to list of players in round
        self.m_players[player.m_name] = player
    
    
    def update_player_position (self, name, posX, posY, ang, spotted,dead):
        #Despite name, updates position, view ang (does not work), deadiness and wether they are visible or not
        self.m_players[name].update_position([posX, posY], ang, spotted, dead)
    
    
    def print_round (self):
        #relised after implementation that I should have used a scatter graph for this... 
        plt.ion()
        figure = plt.figure()
        plt.axis([-2600, 2100, -1200, 3200])
        plot_list = []
        max_frames = 0
        img = plt.imread("de_dust_map.png")
        plt.imshow(img, extent=[-2600,2100,-1200,3200])
        
        for key, play in self.m_players.items():
            if play.m_team == "CT":
                o, = plt.plot([],'bo',markersize=13, markeredgewidth=3)
            elif play.m_team == "TERRORIST":
                o, = plt.plot([],'ro',markersize=13, markeredgewidth=3)
            plot_list.append(o)
            
            if max_frames < len(play.m_position_history['position']):
                max_frames = len(play.m_position_history['position'])
        
        plt.show()  
        
        for frame_id in range(max_frames):
            self.draw_frame(frame_id, plot_list, figure)
            #Wait for one tick (think it is 60 ticks per second), changed so i dont have to wait forever to see results
            #Not entirely sure on tick to seconds conversion...TODO
            time.sleep(1/60 * 1/12)
            
            
    def draw_frame(self, fid, plots, fig):
        count=0
        
        for key, play in self.m_players.items():
            if not play.m_position_history['position']: continue
            try:
                if not play.m_position_history['position'][fid]: continue
                
                plots[count].set_xdata(play.m_position_history['position'][fid][0])
                plots[count].set_ydata(play.m_position_history['position'][fid][1])
                
                if play.m_position_history['dead'][fid] == 'Y':
                    plots[count].set_markeredgecolor('k')
                    plots[count].set_marker('x')
                
                else:
                    plots[count].set_marker('o')
                    
                    if play.m_position_history['spotted'][fid] == True:
                        plots[count].set_markeredgecolor('k')
                    
                    else:
                        plots[count].set_markeredgecolor('w')
                
            except:
                pass
            
            count+=1
            fig.canvas.draw()
            fig.canvas.flush_events()

# %%
current_round = [0]

#Callback Functions
def tick_start(msg):
    #If first round has not begun yet, return
    if m_rounds == []: return

    for play in d.entities.players:      
        if not play.team: continue
        if play.team.name == "Spectator": continue
        spotted = play.get_prop('DT_BaseEntity', 'm_bSpotted')
        m_rounds[-1].update_player_position(play.name,int(play.position['x']), int(play.position['y']), play.view_angle, spotted,'N')
            
def round_start (msg, msg1):
    #Update current round
    current_round[0] += 1
    print("Round ", current_round[0])
    m_rounds.append(Round(current_round[0]))
    
    #Add players to the round
    for play in d.entities.players:
        #In professional matches, there are sometimes players that have no team or are spectators
        if not play.team: continue
        if play.team.name == "Spectator": continue
        m_rounds[-1].add_player(Person(play.name,play.team.name))

def death(event, msg):
    #Stolen bit of code, left in unused features...
    for idx, key in enumerate(event['event'].keys):
        if key.name == 'attacker':
            user_id = msg.keys[idx].val_short
            attacker = d.entities.get_by_user_id(user_id)
        elif key.name == 'userid':
            user_id = msg.keys[idx].val_short
            victim = d.entities.get_by_user_id(user_id)
        elif key.name == 'weapon':
            weapon = msg.keys[idx].val_string
        elif key.name == 'headshot':
            headshot = msg.keys[idx].val_bool
            
    if victim and m_rounds:
        print("Player: ",victim.name," died at tick: ",d.current_tick)
        m_rounds[-1].update_player_position(victim.name,int(victim.position['x']), int(victim.position['y']), victim.view_angle, False,'Y')

# %%
#Open and extract DEM file
data = open("deRust.dem", 'rb').read()
d = DemoFile(data)
outFile = open('out.txt', 'w+')

#Add callback events (calls function whenever event occurs in file)
d.add_callback('tick_start', tick_start)
d.add_callback('round_start', round_start)
d.add_callback('player_death', death)

#create list of rounds
m_rounds = []

#Begin parseing file (may take a while)
d.parse()

#Close file
outFile.close()
# Out:
# Round  1
# Player:  JWonderchild  died at tick:  6880
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  12416
# Player:  KRIMZ  died at tick:  14024
# Player:  LDLC shox * CMSTORM  died at tick:  14096
# Player:  olofmeister  died at tick:  14112
# Player:  pronax  died at tick:  14128
# Player:  flusha  died at tick:  14208
# Round  2
# Player:  pronax  died at tick:  18576
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  26128
# Player:  flusha  died at tick:  26344
# Player:  LDLC shox * CMSTORM  died at tick:  27024
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  27040
# Player:  olofmeister  died at tick:  27096
# Player:  LDLC Happy * CMSTORM  died at tick:  28496
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  29040
# Round  3
# Player:  KRIMZ  died at tick:  38920
# Player:  flusha  died at tick:  39288
# Player:  olofmeister  died at tick:  43720
# Round  4
# Player:  KRIMZ  died at tick:  57418
# Player:  olofmeister  died at tick:  58738
# Player:  pronax  died at tick:  59370
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  59514
# Player:  flusha  died at tick:  59690
# Player:  JWonderchild  died at tick:  60378
# Round  5
# Player:  olofmeister  died at tick:  66589
# Player:  KRIMZ  died at tick:  69493
# Player:  JWonderchild  died at tick:  71757
# Player:  LDLC Happy * CMSTORM  died at tick:  72005
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  74589
# Player:  flusha  died at tick:  76205
# Player:  pronax  died at tick:  78125
# Round  6
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  89072
# Player:  olofmeister  died at tick:  89088
# Player:  LDLC Happy * CMSTORM  died at tick:  89136
# Player:  pronax  died at tick:  89440
# Player:  flusha  died at tick:  90192
# Round  7
# Player:  pronax  died at tick:  100277
# Player:  olofmeister  died at tick:  100853
# Player:  flusha  died at tick:  101253
# Player:  LDLC shox * CMSTORM  died at tick:  102045
# Player:  KRIMZ  died at tick:  102149
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  103277
# Player:  JWonderchild  died at tick:  104997
# Round  8
# Player:  JWonderchild  died at tick:  108679
# Player:  olofmeister  died at tick:  109423
# Player:  LDLC Happy * CMSTORM  died at tick:  114727
# Player:  flusha  died at tick:  116471
# Player:  pronax  died at tick:  117567
# Player:  KRIMZ  died at tick:  118807
# Round  9
# Player:  KRIMZ  died at tick:  123752
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  123808
# Player:  JWonderchild  died at tick:  124160
# Player:  LDLC Happy * CMSTORM  died at tick:  124256
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  124920
# Player:  flusha  died at tick:  125192
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  128216
# Player:  LDLC shox * CMSTORM  died at tick:  128744
# Round  10
# Player:  LDLC shox * CMSTORM  died at tick:  138768
# Player:  KRIMZ  died at tick:  138840
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  142992
# Player:  JWonderchild  died at tick:  143152
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  143528
# Player:  olofmeister  died at tick:  143624
# Player:  flusha  died at tick:  145120
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  145392
# Round  11
# Player:  pronax  died at tick:  153049
# Player:  olofmeister  died at tick:  154081
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  154889
# Player:  KRIMZ  died at tick:  157081
# Player:  JWonderchild  died at tick:  158257
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  158801
# Player:  flusha  died at tick:  162193
# Round  12
# Player:  JWonderchild  died at tick:  166321
# Player:  pronax  died at tick:  167817
# Player:  KRIMZ  died at tick:  168545
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  169145
# Player:  LDLC Happy * CMSTORM  died at tick:  170649
# Round  13
# Player:  LDLC shox * CMSTORM  died at tick:  185778
# Player:  LDLC Happy * CMSTORM  died at tick:  186138
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  187986
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  188626
# Player:  JWonderchild  died at tick:  188874
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  189450
# Round  14
# Player:  LDLC shox * CMSTORM  died at tick:  195746
# Player:  flusha  died at tick:  196218
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  196666
# Player:  KRIMZ  died at tick:  196738
# Player:  pronax  died at tick:  198242
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  199610
# Player:  LDLC Happy * CMSTORM  died at tick:  200290
# Player:  JWonderchild  died at tick:  200786
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  200914
# Round  15
# Player:  KRIMZ  died at tick:  212444
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  212508
# Player:  LDLC Happy * CMSTORM  died at tick:  212948
# Player:  flusha  died at tick:  212988
# Player:  pronax  died at tick:  213556
# Player:  olofmeister  died at tick:  214484
# Player:  JWonderchild  died at tick:  217308
# Round  16
# Player:  LDLC shox * CMSTORM  died at tick:  236602
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  236714
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  238098
# Player:  flusha  died at tick:  238178
# Player:  LDLC Happy * CMSTORM  died at tick:  238506
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  240114
# Round  17
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  245538
# Player:  LDLC Happy * CMSTORM  died at tick:  247178
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  248394
# Player:  pronax  died at tick:  249082
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  249706
# Player:  LDLC shox * CMSTORM  died at tick:  249954
# Round  18
# Player:  JWonderchild  died at tick:  254791
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  255007
# Player:  olofmeister  died at tick:  256143
# Player:  pronax  died at tick:  259927
# Player:  LDLC Happy * CMSTORM  died at tick:  260183
# Player:  KRIMZ  died at tick:  260303
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  260383
# Player:  flusha  died at tick:  263535
# Round  19
# Player:  JWonderchild  died at tick:  269767
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  269927
# Player:  flusha  died at tick:  270031
# Player:  LDLC Happy * CMSTORM  died at tick:  270071
# Player:  KRIMZ  died at tick:  270295
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  270679
# Player:  LDLC shox * CMSTORM  died at tick:  274207
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  275111
# Round  20
# Player:  JWonderchild  died at tick:  281193
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  281289
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  281393
# Player:  LDLC Happy * CMSTORM  died at tick:  285457
# Player:  LDLC shox * CMSTORM  died at tick:  285801
# Player:  olofmeister  died at tick:  286041
# Round  21
# Player:  pronax  died at tick:  300777
# Player:  KRIMZ  died at tick:  302129
# Player:  LDLC shox * CMSTORM  died at tick:  302913
# Player:  olofmeister  died at tick:  302985
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  303081
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  304113
# Player:  JWonderchild  died at tick:  304329
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  304401
# Player:  flusha  died at tick:  307537
# Round  22
# Player:  JWonderchild  died at tick:  313774
# Player:  flusha  died at tick:  313790
# Player:  KRIMZ  died at tick:  314758
# Player:  LDLC Happy * CMSTORM  died at tick:  315278
# Player:  olofmeister  died at tick:  315318
# Player:  pronax  died at tick:  316038
# Round  23
# Player:  LDLC shox * CMSTORM  died at tick:  322582
# Player:  LDLC Happy * CMSTORM  died at tick:  324598
# Player:  olofmeister  died at tick:  326686
# Player:  LDLC SMITHZZ * CMSTORM  died at tick:  327918
# Player:  JWonderchild  died at tick:  329382
# Player:  flusha  died at tick:  332470
# Round  24
# Player:  olofmeister  died at tick:  340952
# Player:  pronax  died at tick:  341240
# Player:  flusha  died at tick:  342208
# Player:  JWonderchild  died at tick:  342736
# Player:  LDLC NBKTANK- * CMSTORM  died at tick:  343112
# Player:  KRIMZ  died at tick:  344408
# Round  25
# Player:  olofmeister  died at tick:  348716
# Player:  flusha  died at tick:  349164
# Player:  KRIMZ  died at tick:  349524
# Player:  LDLC kiokiNg/w/ * CMSTORM  died at tick:  349596
# Player:  JWonderchild  died at tick:  350180
# Player:  LDLC Happy * CMSTORM  died at tick:  350708
# Player:  pronax  died at tick:  351044
# Round  26
# Player:  pronax  died at tick:  357425
# Player:  KRIMZ  died at tick:  363977
# Player:  flusha  died at tick:  364217
# Player:  JWonderchild  died at tick:  364473
# Player:  olofmeister  died at tick:  365273

# %%
# %matplotlib qt

#Print Round 0
m_rounds[0].print_round()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a13991ed1ae2> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'qt')
# ----> 2 m_rounds[0].print_round()
#
# <ipython-input-3-f49ba64d34ef> in print_round(self)
#      39
#      40         for frame_id in range(max_frames):
# ---> 41             self.draw_frame(frame_id, plot_list, figure)
#      42             #Wait for one tick (think it is 60 ticks per second), changed so i dont have to wait forever to see results
#      43             time.sleep(1/60 * 1/12)
#
# <ipython-input-3-f49ba64d34ef> in draw_frame(self, fid, plots, fig)
#      73
#      74             count+=1
# ---> 75             fig.canvas.draw()
#      76             fig.canvas.flush_events()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     431             # if toolbar:
#     432             #     toolbar.set_cursor(cursors.WAIT)
# --> 433             self.figure.draw(self.renderer)
#     434             # A GUI class may be need to update a window using this draw, so
#     435             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1193
#    1194         for tick in ticks_to_draw:
# -> 1195             tick.draw(renderer)
#    1196
#    1197         # scale up the axis label box to also find the neighbors, not
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer)
#     302
#     303         if self.label1On:
# --> 304             self.label1.draw(renderer)
#     305         if self.label2On:
#     306             self.label2.draw(renderer)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/text.py in draw(self, renderer)
#     753                     textrenderer.draw_text(gc, x, y, clean_line,
#     754                                            textobj._fontproperties, angle,
# --> 755                                            ismath=ismath, mtext=mtext)
#     756
#     757         gc.restore()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     216
#     217         self._renderer.draw_text_image(
# --> 218             font, np.round(x - xd + xo), np.round(y + yd + yo) + 1, angle, gc)
#     219
#     220     def get_text_width_height_descent(self, s, prop, ismath):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in get_dashes(self)
#     928         return None, None
#     929
# --> 930     def get_dashes(self):
#     931         """
#     932         Return the dash information as an offset dashlist tuple.
#
# KeyboardInterrupt:

# %%
#creating seperate class to deal with interesting analysis as modifiying round class 
#requires a full restart to test changes
class round_heat_map:
    def __init__(self):
        self
        
    def print_round (self):
        
    def print_frame (self):
        
    def define_player_info (self, player_info):
